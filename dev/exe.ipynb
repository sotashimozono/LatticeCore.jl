# %% [markdown]
# LatticeCoreを使って Lattice2Dの内容をここに移植できたらそれは一つのゴールなんじゃないかと思う

# %%
using LatticeCore
# Out:
# [ Info: Precompiling LatticeCore [042fd91a-3fce-461f-9bc9-903d8e3f68e7] (cache misses: include_dependency fsize change (2))
#
# SYSTEM: caught exception of type :MethodError while trying to print a failed Task notice; giving up
